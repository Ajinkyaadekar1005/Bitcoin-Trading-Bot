# %%
import numpy as np
import talib 
import websocket
import json
import matplotlib.pyplot as plt
import matplotlib.animation as animation
        
long_position=0
short_position=0     
investments=[]
portfolio= 0


opens=[]
closes=[]
highs=[]
lows=[]
candle_close_time=[]       


fund = 10000
money_end = fund
trade_fund = money_end *0.5


symbol = 'btcusdt'                           # asset symbol
interval = '1m'                              # asset interval
socket = f'wss://stream.binance.com:9443/ws/{symbol}@kline_{interval}'


SMA_timeperiod = 2
aroon_time_period = 3
aroon_up = []
aroon_down = []

# %%
def buy (allocated_amount,price):
    global portfolio,investments,money_end
    
    if money_end > 0:
        quantity = allocated_amount/price
        portfolio += quantity
        money_end -= quantity*price

        print(f'Quantity Bought: {quantity}')
        print(f'Updated Portfolio: {portfolio}')
        print(f'Remaning Funds: {money_end}')
        print(f'Long position flag: {long_position}')
        
        if  investments == []:
            investments.append(allocated_amount)
            print(f'Investment History:{investments}')
        else:
            investments.append(allocated_amount)
            investments[-1] += investments[-2]
            print(f'Investment History:{investments}')
    
    else:
        print("Not Enough balance in the account to execute the trade!")
        # print(f'Final Quantity Bought: {quantity}')
        # print(f'Final Updated Portfolio: {portfolio}')
        # print(f'Final Remaning Funds: {money_end}')



def sell (allocated_amount,price):
    global portfolio,investments,money_end
    
    if money_end > 0:
        quantity = allocated_amount/price
        portfolio -= quantity
        money_end += quantity*price

        print(f'Quantity Sold: {quantity}')
        print(f'Updated Portfolio: {portfolio}')
        print(f'Total Funds: {money_end}')
        print(f'Sell position flag: {short_position}')
        
        if  investments == []:
            investments.append(-allocated_amount)
            print(f'Investment History:{investments}')
        else:
            investments.append(-allocated_amount)
            investments[-1] += investments[-2]
            print(f'Investment History:{investments}')
    
    else:
        print("Not Enough balance in the account to execute the trade!")

# %%
def on_close(ws):
    print("connection closed")


def on_message(ws, message):
    global opens,closes,highs,lows, candle_close_time, aroon_up, aroon_down
    json_message = json.loads(message)
    candlesticks = json_message["k"]
    candlesticks_closed, candlesticks_closedTime, open, close, high, low = candlesticks['x'], candlesticks['T'], candlesticks['o'], candlesticks['c'], candlesticks['h'], candlesticks['l']
    


    if candlesticks_closed:
        opens.append(float(open))
        highs.append(float(high))
        closes.append(float(close))
        lows.append(float(low))
        candle_close_time.append(float(candlesticks_closedTime))

        aroon_up, aroon_down = talib.AROON(np.array(highs),np.array(lows),aroon_time_period)
        SMA_9 = talib.SMA(np.array(closes), SMA_timeperiod)
        # print(aroon_up,aroon_down)
        # print(SMA_9)

        # BUY STRATEGY
        if  long_position == 0 and aroon_up[-1] > aroon_down[-1] and aroon_up[-2] < aroon_down[-2] and \
            closes[-1] >  SMA_9[-1]:
            print(f'Buy order initiated at price ${closes[-1]}')
            print(f'Timestamp:{candle_close_time[-1]}')
            long_position = 1
            print(f'In strategy buy flag :{long_position}')
            buy (trade_fund, price= closes[-1])
            print("____________________________________________")
            buy_quantity = trade_fund / closes[-1]
            buy_price = closes[-1]
            

        if long_position == 1 and closes[-1] <= SMA_9[-1] :
            buytrade_exit_price = closes[-1]
            print(f'Current price is : ${closes[-1]}. Waiting for price to reach {buytrade_exit_price}')
            print(f'Buy exit initiated at price ${closes[-1]}')
            print(f'Timestamp:{candle_close_time[-1]}')
            long_position = 0
            print(f'In strategy buy flag :{long_position}')
            afterbuy_trade_fund = buy_quantity * buytrade_exit_price
            sell(afterbuy_trade_fund, price=buytrade_exit_price)
            print("****************END OF TRADE****************")
            print(" ")


        # SELL STRATEGY
        if  short_position == 0 and aroon_down[-1] > aroon_up[-1] and aroon_down[-2] < aroon_up[-2] and \
            closes[-1] <  SMA_9[-1]:
            print(f'Short order initiated at price ${closes[-1]}')
            print(f'Timestamp:{candle_close_time[-1]}')
            short_position = 1
            print(f'In strategy sell flag :{short_position}')
            sell (trade_fund, price= closes[-1])
            print("____________________________________________")
            sell_quantity = trade_fund / closes[-1]
            sell_price = closes[-1]

        if  short_position == 1 and closes[-1] >= SMA_9[-1]:
            selltrade_exit_price = closes[-1]
            print(f'Current price is : ${closes[-1]}. Waiting for price to reach {selltrade_exit_price}')
            print(f'Short exit initiated at price ${selltrade_exit_price}')
            print(f'Timestamp:{candle_close_time[-1]}')
            short_position = 0
            print(f'In strategy buy flag :{short_position}')
            aftersell_trade_fund = sell_quantity * selltrade_exit_price
            buy(aftersell_trade_fund, price=selltrade_exit_price)
            print("****************END OF TRADE****************")
            print(" ")

ws = websocket.WebSocketApp(socket, on_message = on_message, on_close = on_close)
ws.run_forever()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\Study\Finance Projects\Bitcoin Paper Trading\test.ipynb Cell 3 in 7
#      <a href='vscode-notebook-cell:/d%3A/Study/Finance%20Projects/Bitcoin%20Paper%20Trading/test.ipynb#W2sZmlsZQ%3D%3D?line=72'>73</a>             print(" ")
#      <a href='vscode-notebook-cell:/d%3A/Study/Finance%20Projects/Bitcoin%20Paper%20Trading/test.ipynb#W2sZmlsZQ%3D%3D?line=74'>75</a> ws = websocket.WebSocketApp(socket, on_message = on_message, on_close = on_close)
# ---> <a href='vscode-notebook-cell:/d%3A/Study/Finance%20Projects/Bitcoin%20Paper%20Trading/test.ipynb#W2sZmlsZQ%3D%3D?line=75'>76</a> ws.run_forever()
#
# File c:\Users\WORKSTATION\AppData\Local\Programs\Python\Python39\lib\site-packages\websocket\_app.py:483, in WebSocketApp.run_forever(self, sockopt, sslopt, ping_interval, ping_timeout, ping_payload, http_proxy_host, http_proxy_port, http_no_proxy, http_proxy_auth, http_proxy_timeout, skip_utf8_validation, host, origin, dispatcher, suppress_origin, proxy_type, reconnect)
#     480 custom_dispatcher = bool(dispatcher)
#     481 dispatcher = self.create_dispatcher(ping_timeout, dispatcher, parse_url(self.url)[3])
# --> 483 setSock()
#     484 if not custom_dispatcher and reconnect:
#     485     while self.keep_running:
#
# File c:\Users\WORKSTATION\AppData\Local\Programs\Python\Python39\lib\site-packages\websocket\_app.py:413, in WebSocketApp.run_forever.<locals>.setSock(reconnecting)
#     411     dispatcher.read(self.sock.sock, read, check)
#     412 except (WebSocketConnectionClosedException, ConnectionRefusedError, KeyboardInterrupt, SystemExit, Exception) as e:
# --> 413     handleDisconnect(e, reconnecting)
#
# File c:\Users\WORKSTATION\AppData\Local\Programs\Python\Python39\lib\site-packages\websocket\_app.py:411, in WebSocketApp.run_forever.<locals>.setSock(reconnecting)
#     407         self._start_ping_thread()
#     409     self._callback(self.on_open)
# --> 411     dispatcher.read(self.sock.sock, read, check)
#     412 except (WebSocketConnectionClosedException, ConnectionRefusedError, KeyboardInterrupt, SystemExit, Exception) as e:
#     413     handleDisconnect(e, reconnecting)
#
# File c:\Users\WORKSTATION\AppData\Local\Programs\Python\Python39\lib\site-packages\websocket\_app.py:87, in SSLDispatcher.read(self, sock, read_callback, check_callback)
#      85 def read(self, sock, read_callback, check_callback):
#      86     while self.app.keep_running:
# ---> 87         r = self.select()
#      88         if r:
#      89             if not read_callback():
#
# File c:\Users\WORKSTATION\AppData\Local\Programs\Python\Python39\lib\site-packages\websocket\_app.py:101, in SSLDispatcher.select(self)
#      98 sel = selectors.DefaultSelector()
#      99 sel.register(sock, selectors.EVENT_READ)
# --> 101 r = sel.select(self.ping_timeout)
#     102 sel.close()
#     104 if len(r) > 0:
#
# File c:\Users\WORKSTATION\AppData\Local\Programs\Python\Python39\lib\selectors.py:324, in SelectSelector.select(self, timeout)
#     322 ready = []
#     323 try:
# --> 324     r, w, _ = self._select(self._readers, self._writers, [], timeout)
#     325 except InterruptedError:
#     326     return ready
#
# File c:\Users\WORKSTATION\AppData\Local\Programs\Python\Python39\lib\selectors.py:315, in SelectSelector._select(self, r, w, _, timeout)
#     314 def _select(self, r, w, _, timeout=None):
# --> 315     r, w, x = select.select(r, w, w, timeout)
#     316     return r, w + x, []
#
# KeyboardInterrupt:
